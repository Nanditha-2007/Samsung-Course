# %%
import pandas as pd
import numpy as np

# %%
my_index=['a','b','c']
my_values=[222,333,444]
my_dict={'a':222,'b':333,'c':444}
my_arr=np.array(my_values)

# %%
#seriesn with values
pd.Series(my_values)
#series with val and index
# Out:
# 0    222
# 1    333
# 2    444
# dtype: int64

# %%
pd.Series(data=my_values,index=my_index)
# Out:
# a    222
# b    333
# c    444
# dtype: int64

# %%
pd.Series(my_arr)
# Out:
# 0    222
# 1    333
# 2    444
# dtype: int64

# %%
s=pd.Series(my_dict,name="dict series")
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.name
# Out:
# 'dict series'

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([222, 333, 444])

# %%
s
# Out:
# a    222
# b    333
# c    444
# Name: dict series, dtype: int64

# %%
s[1]
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13428\878419959.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[1]
# np.int64(333)

# %%
s['a']
# Out:
# np.int64(222)

# %%
s[2:4]
# Out:
# c    444
# Name: dict series, dtype: int64

# %%
s[['a','c']]
# Out:
# a    222
# c    444
# Name: dict series, dtype: int64

# %%
s1=pd.Series(data=[1,2,3,4],index=['d','b','c','a'])
print(s1)
s2=pd.Series(data=[1,2,3,4],index=['a','b','d','e'])
print(s2)
print(s1+s2)
# Out:
# d    1
# b    2
# c    3
# a    4
# dtype: int64
# a    1
# b    2
# d    3
# e    4
# dtype: int64
# a    5.0
# b    4.0
# c    NaN
# d    4.0
# e    NaN
# dtype: float64

# %%
s1-s2
# Out:
# a    3.0
# b    0.0
# c    NaN
# d   -2.0
# e    NaN
# dtype: float64

# %%
s1*s2
# Out:
# a    4.0
# b    4.0
# c    NaN
# d    3.0
# e    NaN
# dtype: float64

# %%
s1/s2
# Out:
# a    4.000000
# b    1.000000
# c         NaN
# d    0.333333
# e         NaN
# dtype: float64

# %%
2*s1
# Out:
# d    2
# b    4
# c    6
# a    8
# dtype: int64

# %%
print(s1.sum())
print(s1.mean())
print(s1.median())
print(s1.max())
print(s1.std())
s1.sort_values()
s1.sort_index()
# Out:
# 10
# 2.5
# 2.5
# 4
# 1.2909944487358056
# a    4
# b    2
# c    3
# d    1
# dtype: int64

# %%
ser_height=pd.Series([165.3,170.1,175.0,182.1,168.0,162.0,155.2,176.9,178.5,176.1,167.1,180.0,162.2,176.1,158.2,168.6,169.2],name='height')
ser_height
# Out:
# 0     165.3
# 1     170.1
# 2     175.0
# 3     182.1
# 4     168.0
# 5     162.0
# 6     155.2
# 7     176.9
# 8     178.5
# 9     176.1
# 10    167.1
# 11    180.0
# 12    162.2
# 13    176.1
# 14    158.2
# 15    168.6
# 16    169.2
# Name: height, dtype: float64

# %%
ser_height.apply(lambda x:x/100)
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
sdata={'ohio':3500,'texas':71000,'oregon':16000,'utah':5000}
obj1=pd.Series(sdata)
obj1
# Out:
# ohio       3500
# texas     71000
# oregon    16000
# utah       5000
# dtype: int64

# %%
states=['california','ohio','oregon','texas']
obj2=pd.Series(sdata,index=states)
obj2
# Out:
# california        NaN
# ohio           3500.0
# oregon        16000.0
# texas         71000.0
# dtype: float64

# %%
pd.isnull(obj2)
# Out:
# california     True
# ohio          False
# oregon        False
# texas         False
# dtype: bool

# %%
pd.notnull(obj2)
# Out:
# california    False
# ohio           True
# oregon         True
# texas          True
# dtype: bool

# %%
obj2.isnull()
# Out:
# california     True
# ohio          False
# oregon        False
# texas         False
# dtype: bool

# %%
obj2.notnull()
# Out:
# california    False
# ohio           True
# oregon         True
# texas          True
# dtype: bool

# %%
obj2.name='population'
obj2.index.name='state'
obj2
# Out:
# state
# california        NaN
# ohio           3500.0
# oregon        16000.0
# texas         71000.0
# Name: population, dtype: float64

# %%
obj1.index=['bob','steve','jeff','ryan']
obj1
# Out:
# bob       3500
# steve    71000
# jeff     16000
# ryan      5000
# dtype: int64
