# %%
#bernouli trial->> binomial distribution

# %%
import numpy as np
from scipy.stats import binom,poisson

print("="*60)
print(" ai/mlapplication: spam email detection")
print("="*60)

#part 1
print("\n bernouli distribution")
print("="*40)
#probability tht a mail is spam
p=0.2
#generate one mail
email=np.random.binomial(1,p)
print(" probability of spam: ",p)
if email==1:
    print("result: the email is spam")
else:
    print("result: the email is not spam")
print(" interpretation\n")
print(" bernouli distribution model a single email")
print("possible outcomes")
print("1-> spam")
print("0->not spam")

#part 2 binomial distribution
print(" \n binomial distribution")
print("-"*40)
n=15
x=4
binomial_prob=binom.pmf(x,n,p)
print(" total emails(n): ",n)
print("probability of spam(p): ",p)
print("required spam emails(x)= ",x)
print(" probability of exactly 4 spam mails: ")
print("P(x=4)= ",round(binomial_prob,6))
#part 3 poissons distribution
lam=3
x=5
poisson_prob=poisson.pmf(x,lam)
print("p(X=5)= ",round(poisson_prob,6))
# Out:
# ...
#  ai/mlapplication: spam email detection
# ...
#
#  bernouli distribution
# ...
#  probability of spam:  0.2
# result: the email is not spam
#  interpretation
#
#  bernouli distribution model a single email
# possible outcomes
# 1-> spam
# 0->not spam
#
#  binomial distribution
# ----------------------------------------
#  total emails(n):  15
# probability of spam(p):  0.2
# required spam emails(x)=  4
#  probability of exactly 4 spam mails:
# P(x=4)=  0.187604
# p(X=5)=  0.100819
