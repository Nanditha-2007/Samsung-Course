# %%
import numpy as np
a1=np.ones(5)
print(a1)
# Out:
# [1. 1. 1. 1. 1.]

# %%
print(type(a1[0]))
# Out:
# <class 'numpy.float64'>

# %%
a2=np.zeros(5)
print(type(a2[0]))
# Out:
# <class 'numpy.float64'>

# %%
a2=np.ones((2,3),dtype='int64')
print(a2)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
a2.astype('float32')
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]], dtype=float32)

# %%
#functions
'''np.ones(r,c)
a.astype('')
np.zeros()
np.arrange(1,10,2)
'''
# Out:
# "np.ones(r,c)\na.astype('')\nnp.zeros()\nnp.arrange(1,10,2)\n"

# %%
'''properties
ndim
shape
size
